# %%
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup

# %%
def parse_table(table, len_table):
    result = np.empty([0,2])
    for i in range(2,len_table):
        a = str(table[i])
        delim = a.find('title=')
        if delim == -1:
            continue
        a = a[delim + 6:]
        delim = a.find('>')
        a = a[delim:]
        delim = a.find('<')
        album = a[1:delim]
        album = album.replace("'", "")
        delim = a.find('US:')
        if delim == -1:
            delim = a.find('US</a>:')
            if delim == -1:
                continue
        a = a[delim:]
        for i, c in enumerate(a):
            if c.isdigit():
                delim = i
                break
        a = a[delim:]
        delim = a.find('<')
        sale = a[:delim]
        sale = float(sale.replace(',',''))
        result = np.append(result, [[album, sale]],axis = 0)
    return result

# %%
with open ("wiki_json.txt", "r") as my_file:
    data = my_file.readlines()

# %%
with open ("artists.txt", "r") as my_file:
    artists = my_file.readlines()

# %%
len_file = len(data)

# %%
wiki_result = np.empty([0,3])
for i in range(len_file):
    html_doc = data[i]
    soup = BeautifulSoup(html_doc, 'html.parser')
    tr = soup.find_all('tr')
    length = len(tr)
    result = parse_table(tr, length)
    length = len(result)
    artist = [[artists[i] for j in range(1)] for j in range(length)]
    tempo = np.hstack((artist, result))
    wiki_result = np.append(wiki_result, tempo, axis = 0)

# %%
col_names = ['Artist', 'Album', 'US sales']
df = pd.DataFrame(data=wiki_result, columns=col_names)

# %%
df['Artist'] = df['Artist'].str.replace('\n','')
df
# Out:
#                     Artist                               Album    US sales
# 0           Kendrick Lamar                          Section.80    130000.0
# 1           Kendrick Lamar              Good Kid, M.A.A.D City   1720000.0
# 2           Kendrick Lamar                 To Pimp a Butterfly   1050000.0
# 3           Kendrick Lamar                                Damn   1002000.0
# 4         Childish Gambino                                Camp    242000.0
# 5         Childish Gambino                Because the Internet    796000.0
# 6         Childish Gambino                \"Awaken, My Love!\"   1320000.0
# 7               Bruno Mars            Doo-Wops &amp; Hooligans   2626000.0
# 8               Bruno Mars                  Unorthodox Jukebox   2574000.0
# 9               Bruno Mars                           24K Magic   1000000.0
# 10                   Drake                      Thank Me Later   1830000.0
# 11                   Drake                           Take Care   2338000.0
# 12                   Drake                Nothing Was the Same   1783000.0
# 13                   Drake                               Views   1730000.0
# 14                   Drake                            Scorpion    381000.0
# 15                  Eminem                            Infinite      1000.0
# 16                  Eminem                   The Slim Shady LP   4000000.0
# 17                  Eminem             The Marshall Mathers LP  11000000.0
# 18                  Eminem                     The Eminem Show  10600000.0
# 19                  Eminem                              Encore   5343000.0
# 20                  Eminem                             Relapse   2363000.0
# 21                  Eminem                            Recovery   4867000.0
# 22                  Eminem           The Marshall Mathers LP 2   2244000.0
# 23                  Eminem                             Revival    435000.0
# 24                  Eminem                            Kamikaze    493000.0
# 25                  Eminem             Music to Be Murdered By    117000.0
# 26       Justin Timberlake                           Justified   3969000.0
# 27       Justin Timberlake                FutureSex/LoveSounds   4720000.0
# 28       Justin Timberlake                The 20/20 Experience   2579000.0
# 29       Justin Timberlake  The 20/20 Experience \u2013 2 of 2   1137000.0
# ..                     ...                                 ...         ...
# 138  Red Hot Chili Peppers                    Stadium Arcadium   2500000.0
# 139  Red Hot Chili Peppers                         Im with You    650000.0
# 140  Red Hot Chili Peppers                         The Getaway    500000.0
# 141                Rihanna                    Music of the Sun    623000.0
# 142                Rihanna                      A Girl like Me   1400000.0
# 143                Rihanna                  Good Girl Gone Bad   2800000.0
# 144                Rihanna                             Rated R   1130000.0
# 145                Rihanna                                Loud   1800000.0
# 146                Rihanna                      Talk That Talk   1150000.0
# 147                Rihanna                        Unapologetic   1200000.0
# 148                Rihanna                                Anti    603000.0
# 149           Taylor Swift                        Taylor Swift   5720000.0
# 150           Taylor Swift                            Fearless   7180000.0
# 151           Taylor Swift                           Speak Now   4694000.0
# 152           Taylor Swift                                 Red   4465000.0
# 153           Taylor Swift                                1989   6215000.0
# 154           Taylor Swift                          Reputation   2230000.0
# 155           Taylor Swift                               Lover   1085000.0
# 156           Travis Scott                               Rodeo    110000.0
# 157           Travis Scott     Birds in the Trap Sing McKnight     53000.0
# 158           Travis Scott                          Astroworld    518000.0
# 159             The Weeknd                           Kiss Land    273000.0
# 160             The Weeknd           Beauty Behind the Madness   1230000.0
# 161             The Weeknd                             Starboy    484000.0
# 162           Wu-Tang Clan     Enter the Wu-Tang (36 Chambers)   3000000.0
# 163           Wu-Tang Clan                     Wu-Tang Forever   2000000.0
# 164           Wu-Tang Clan                               The W   1100000.0
# 165           Wu-Tang Clan                           Iron Flag    687000.0
# 166           Wu-Tang Clan                          8 Diagrams    202000.0
# 167           Wu-Tang Clan                   A Better Tomorrow     60000.0
#
# [168 rows x 3 columns]

# %%
list(df['Album'])
# Out:
# ['Section.80',
#  'Good Kid, M.A.A.D City',
#  'To Pimp a Butterfly',
#  'Damn',
#  'Camp',
#  'Because the Internet',
#  '\\"Awaken, My Love!\\"',
#  'Doo-Wops &amp; Hooligans',
#  'Unorthodox Jukebox',
#  '24K Magic',
#  'Thank Me Later',
#  'Take Care',
#  'Nothing Was the Same',
#  'Views',
#  'Scorpion',
#  'Infinite',
#  'The Slim Shady LP',
#  'The Marshall Mathers LP',
#  'The Eminem Show',
#  'Encore',
#  'Relapse',
#  'Recovery',
#  'The Marshall Mathers LP 2',
#  'Revival',
#  'Kamikaze',
#  'Music to Be Murdered By',
#  'Justified',
#  'FutureSex/LoveSounds',
#  'The 20/20 Experience',
#  'The 20/20 Experience \\u2013 2 of 2',
#  'Man of the Woods',
#  'My World 2.0',
#  'Under the Mistletoe',
#  'Believe',
#  'Purpose',
#  'CD',
#  'Colour the Small One',
#  'Some People Have Real Problems',
#  '1000 Forms of Fear',
#  'Everyday Is Christmas',
#  'Yours Truly',
#  'My Everything',
#  'Dangerous Woman',
#  'Sweetener',
#  'Thank U, Next',
#  'Dangerously in Love',
#  'BDay',
#  'I Am... Sasha Fierce',
#  '4',
#  'Beyonc\\u00e9',
#  'Lemonade',
#  'Gorillaz',
#  'Demon Days',
#  'Plastic Beach',
#  'Chris Brown',
#  'Exclusive',
#  'Graffiti',
#  'F.A.M.E.',
#  'Fortune',
#  'X',
#  'Royalty',
#  'Heartbreak on a Full Moon',
#  'Indigo',
#  'Reasonable Doubt',
#  'In My Lifetime, Vol. 1',
#  'Vol. 2... Hard Knock Life',
#  'Vol. 3... Life and Times of S. Carter',
#  'The Dynasty: Roc La Familia',
#  'The Blueprint',
#  'The Blueprint 2: The Gift &amp; The Curse',
#  'The Black Album',
#  'Kingdom Come',
#  'American Gangster',
#  'The Blueprint 3',
#  'Magna Carta... Holy Grail',
#  '4:44',
#  'Night Visions',
#  'Smoke + Mirrors',
#  'Evolve',
#  'Origins',
#  'Thankful',
#  'Breakaway',
#  'My December',
#  'All I Ever Wanted',
#  'Stronger',
#  'Wrapped in Red',
#  'Piece by Piece',
#  'Meaning of Life',
#  'The Fame',
#  'Born This Way',
#  'Artpop',
#  'Cheek to Cheek',
#  'Joanne',
#  'Tha Block Is Hot',
#  'Tha Carter',
#  'Tha Carter II',
#  'Tha Carter III',
#  'Rebirth',
#  'I Am Not a Human Being',
#  'Tha Carter IV',
#  'I Am Not a Human Being II',
#  'Tha Carter V',
#  'Funeral',
#  'The College Dropout',
#  'Late Registration',
#  'Graduation',
#  '808s &amp; Heartbreak',
#  'My Beautiful Dark Twisted Fantasy',
#  'Yeezus',
#  'Ye',
#  'Jesus Is King',
#  'Hybrid Theory',
#  'Meteora',
#  'Minutes to Midnight',
#  'A Thousand Suns',
#  'Living Things',
#  'The Hunting Party',
#  'One More Light',
#  'Ride the Lightning',
#  'Master of Puppets',
#  '...And Justice for All',
#  'Metallica',
#  'Load',
#  'Reload',
#  'St. Anger',
#  'Death Magnetic',
#  'Hardwired... to Self-Destruct',
#  'Stoney',
#  'Beerbongs &amp; Bentleys',
#  'Hollywoods Bleeding',
#  'The Red Hot Chili',
#  'Freaky Styley',
#  'The Uplift Mofo Party',
#  'Mothers Milk',
#  'Blood Sugar Sex Magik',
#  'One Hot Minute',
#  'Californication',
#  'By the Way',
#  'Stadium Arcadium',
#  'Im with You',
#  'The Getaway',
#  'Music of the Sun',
#  'A Girl like Me',
#  'Good Girl Gone Bad',
#  'Rated R',
#  'Loud',
#  'Talk That Talk',
#  'Unapologetic',
#  'Anti',
#  'Taylor Swift',
#  'Fearless',
#  'Speak Now',
#  'Red',
#  '1989',
#  'Reputation',
#  'Lover',
#  'Rodeo',
#  'Birds in the Trap Sing McKnight',
#  'Astroworld',
#  'Kiss Land',
#  'Beauty Behind the Madness',
#  'Starboy',
#  'Enter the Wu-Tang (36 Chambers)',
#  'Wu-Tang Forever',
#  'The W',
#  'Iron Flag',
#  '8 Diagrams',
#  'A Better Tomorrow']

# %%
df.loc[df['Album'] == 'Beyonc\\u00e9', 'Album'] = 'Beyonce'

# %%
df.loc[df['Album'] == '\\"Awaken, My Love!\\"', 'Album'] = 'Awaken, My Love!'

# %%
df.loc[df['Album'] == 'The 20/20 Experience \\u2013 2 of 2', 
       'Album'] = 'The 20/20 Experience 2 of 2'

# %%
list(df['Artist'])
# Out:
# ['Kendrick Lamar',
#  'Kendrick Lamar',
#  'Kendrick Lamar',
#  'Kendrick Lamar',
#  'Childish Gambino',
#  'Childish Gambino',
#  'Childish Gambino',
#  'Bruno Mars',
#  'Bruno Mars',
#  'Bruno Mars',
#  'Drake',
#  'Drake',
#  'Drake',
#  'Drake',
#  'Drake',
#  'Eminem',
#  'Eminem',
#  'Eminem',
#  'Eminem',
#  'Eminem',
#  'Eminem',
#  'Eminem',
#  'Eminem',
#  'Eminem',
#  'Eminem',
#  'Eminem',
#  'Justin Timberlake',
#  'Justin Timberlake',
#  'Justin Timberlake',
#  'Justin Timberlake',
#  'Justin Timberlake',
#  'Justin Bieber',
#  'Justin Bieber',
#  'Justin Bieber',
#  'Justin Bieber',
#  'Sia',
#  'Sia',
#  'Sia',
#  'Sia',
#  'Sia',
#  'Ariana Grande',
#  'Ariana Grande',
#  'Ariana Grande',
#  'Ariana Grande',
#  'Ariana Grande',
#  'Beyonce',
#  'Beyonce',
#  'Beyonce',
#  'Beyonce',
#  'Beyonce',
#  'Beyonce',
#  'Corillaz',
#  'Corillaz',
#  'Corillaz',
#  'Chris Brown',
#  'Chris Brown',
#  'Chris Brown',
#  'Chris Brown',
#  'Chris Brown',
#  'Chris Brown',
#  'Chris Brown',
#  'Chris Brown',
#  'Chris Brown',
#  'Jay-Z',
#  'Jay-Z',
#  'Jay-Z',
#  'Jay-Z',
#  'Jay-Z',
#  'Jay-Z',
#  'Jay-Z',
#  'Jay-Z',
#  'Jay-Z',
#  'Jay-Z',
#  'Jay-Z',
#  'Jay-Z',
#  'Jay-Z',
#  'Imagine Dragons',
#  'Imagine Dragons',
#  'Imagine Dragons',
#  'Imagine Dragons',
#  'Kelly Clarkson',
#  'Kelly Clarkson',
#  'Kelly Clarkson',
#  'Kelly Clarkson',
#  'Kelly Clarkson',
#  'Kelly Clarkson',
#  'Kelly Clarkson',
#  'Kelly Clarkson',
#  'Lady Gaga',
#  'Lady Gaga',
#  'Lady Gaga',
#  'Lady Gaga',
#  'Lady Gaga',
#  'Lil Wayne',
#  'Lil Wayne',
#  'Lil Wayne',
#  'Lil Wayne',
#  'Lil Wayne',
#  'Lil Wayne',
#  'Lil Wayne',
#  'Lil Wayne',
#  'Lil Wayne',
#  'Lil Wayne',
#  'Kanye West',
#  'Kanye West',
#  'Kanye West',
#  'Kanye West',
#  'Kanye West',
#  'Kanye West',
#  'Kanye West',
#  'Kanye West',
#  'Linkin Park',
#  'Linkin Park',
#  'Linkin Park',
#  'Linkin Park',
#  'Linkin Park',
#  'Linkin Park',
#  'Linkin Park',
#  'Metallica',
#  'Metallica',
#  'Metallica',
#  'Metallica',
#  'Metallica',
#  'Metallica',
#  'Metallica',
#  'Metallica',
#  'Metallica',
#  'Post Malone',
#  'Post Malone',
#  'Post Malone',
#  'Red Hot Chili Peppers',
#  'Red Hot Chili Peppers',
#  'Red Hot Chili Peppers',
#  'Red Hot Chili Peppers',
#  'Red Hot Chili Peppers',
#  'Red Hot Chili Peppers',
#  'Red Hot Chili Peppers',
#  'Red Hot Chili Peppers',
#  'Red Hot Chili Peppers',
#  'Red Hot Chili Peppers',
#  'Red Hot Chili Peppers',
#  'Rihanna',
#  'Rihanna',
#  'Rihanna',
#  'Rihanna',
#  'Rihanna',
#  'Rihanna',
#  'Rihanna',
#  'Rihanna',
#  'Taylor Swift',
#  'Taylor Swift',
#  'Taylor Swift',
#  'Taylor Swift',
#  'Taylor Swift',
#  'Taylor Swift',
#  'Taylor Swift',
#  'Travis Scott',
#  'Travis Scott',
#  'Travis Scott',
#  'The Weeknd',
#  'The Weeknd',
#  'The Weeknd',
#  'Wu-Tang Clan',
#  'Wu-Tang Clan',
#  'Wu-Tang Clan',
#  'Wu-Tang Clan',
#  'Wu-Tang Clan',
#  'Wu-Tang Clan']

# %%
df.to_csv('data_1.csv', index=False)

# %%
pd.read_csv('data_1.csv')
# Out:
#                     Artist                            Album    US sales
# 0           Kendrick Lamar                       Section.80    130000.0
# 1           Kendrick Lamar           Good Kid, M.A.A.D City   1720000.0
# 2           Kendrick Lamar              To Pimp a Butterfly   1050000.0
# 3           Kendrick Lamar                             Damn   1002000.0
# 4         Childish Gambino                             Camp    242000.0
# 5         Childish Gambino             Because the Internet    796000.0
# 6         Childish Gambino                 Awaken, My Love!   1320000.0
# 7               Bruno Mars         Doo-Wops &amp; Hooligans   2626000.0
# 8               Bruno Mars               Unorthodox Jukebox   2574000.0
# 9               Bruno Mars                        24K Magic   1000000.0
# 10                   Drake                   Thank Me Later   1830000.0
# 11                   Drake                        Take Care   2338000.0
# 12                   Drake             Nothing Was the Same   1783000.0
# 13                   Drake                            Views   1730000.0
# 14                   Drake                         Scorpion    381000.0
# 15                  Eminem                         Infinite      1000.0
# 16                  Eminem                The Slim Shady LP   4000000.0
# 17                  Eminem          The Marshall Mathers LP  11000000.0
# 18                  Eminem                  The Eminem Show  10600000.0
# 19                  Eminem                           Encore   5343000.0
# 20                  Eminem                          Relapse   2363000.0
# 21                  Eminem                         Recovery   4867000.0
# 22                  Eminem        The Marshall Mathers LP 2   2244000.0
# 23                  Eminem                          Revival    435000.0
# 24                  Eminem                         Kamikaze    493000.0
# 25                  Eminem          Music to Be Murdered By    117000.0
# 26       Justin Timberlake                        Justified   3969000.0
# 27       Justin Timberlake             FutureSex/LoveSounds   4720000.0
# 28       Justin Timberlake             The 20/20 Experience   2579000.0
# 29       Justin Timberlake      The 20/20 Experience 2 of 2   1137000.0
# ..                     ...                              ...         ...
# 138  Red Hot Chili Peppers                 Stadium Arcadium   2500000.0
# 139  Red Hot Chili Peppers                      Im with You    650000.0
# 140  Red Hot Chili Peppers                      The Getaway    500000.0
# 141                Rihanna                 Music of the Sun    623000.0
# 142                Rihanna                   A Girl like Me   1400000.0
# 143                Rihanna               Good Girl Gone Bad   2800000.0
# 144                Rihanna                          Rated R   1130000.0
# 145                Rihanna                             Loud   1800000.0
# 146                Rihanna                   Talk That Talk   1150000.0
# 147                Rihanna                     Unapologetic   1200000.0
# 148                Rihanna                             Anti    603000.0
# 149           Taylor Swift                     Taylor Swift   5720000.0
# 150           Taylor Swift                         Fearless   7180000.0
# 151           Taylor Swift                        Speak Now   4694000.0
# 152           Taylor Swift                              Red   4465000.0
# 153           Taylor Swift                             1989   6215000.0
# 154           Taylor Swift                       Reputation   2230000.0
# 155           Taylor Swift                            Lover   1085000.0
# 156           Travis Scott                            Rodeo    110000.0
# 157           Travis Scott  Birds in the Trap Sing McKnight     53000.0
# 158           Travis Scott                       Astroworld    518000.0
# 159             The Weeknd                        Kiss Land    273000.0
# 160             The Weeknd        Beauty Behind the Madness   1230000.0
# 161             The Weeknd                          Starboy    484000.0
# 162           Wu-Tang Clan  Enter the Wu-Tang (36 Chambers)   3000000.0
# 163           Wu-Tang Clan                  Wu-Tang Forever   2000000.0
# 164           Wu-Tang Clan                            The W   1100000.0
# 165           Wu-Tang Clan                        Iron Flag    687000.0
# 166           Wu-Tang Clan                       8 Diagrams    202000.0
# 167           Wu-Tang Clan                A Better Tomorrow     60000.0
#
# [168 rows x 3 columns]
